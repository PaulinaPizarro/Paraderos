# %%
from imageai.Detection import ObjectDetection
import os

execution_path = os.getcwd()

detector = ObjectDetection()
detector.setModelTypeAsRetinaNet()
detector.setModelPath( os.path.join(execution_path , "resnet50_coco_best_v2.0.1.h5"))
detector.loadModel()
custom_objects = detector.CustomObjects(person=True, car=False)
detections = detector.detectCustomObjectsFromImage(input_image=os.path.join(execution_path , "paradero1.png"), output_image_path=os.path.join(execution_path , "paradero1result.png"), custom_objects=custom_objects, minimum_percentage_probability=58)


for eachObject in detections:
    print(eachObject["name"] + " : " + eachObject["percentage_probability"] )
    print("--------------------------------")
# Out:
# person : 91.50187969207764
# --------------------------------
# person : 93.86141896247864
# --------------------------------
# person : 68.4613049030304
# --------------------------------
# person : 74.86366033554077
# --------------------------------
# person : 71.54608964920044
# --------------------------------
# person : 81.63942098617554
# --------------------------------
# person : 87.6948356628418
# --------------------------------

# %%
from IPython.display import Image
Image("paradero1result.png")
